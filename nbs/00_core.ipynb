# %% [markdown]
# # core
#
# > Fill in a module description here

# %% [markdown]
# ## nbdev Module Setup

# %%
#| default_exp core

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
def foo(): pass

# %%
#| hide
import nbdev; nbdev.nbdev_export()

# %%
#| export
def hoo(
    x:int # some var for input
):
   "some gyan about the function"
   pass

# %%
hoo(1)

# %% [markdown]
# do nothing

# %% [markdown]
# ## Web Scraping with BeautifulSoup

# %%
# import beautifil soup
from bs4 import BeautifulSoup
import httpx
page= httpx.get('https://docs.snowflake.com/en/developer-guide/snowflake-python-api/snowflake-python-overview')
soup = BeautifulSoup(page,'html.parser')
soup.select('th')

# %%
soup.select('th')
# Out:
# [<th class="head"><p>Guide</p></th>, <th class="head"><p>Description</p></th>]

# %%
# slecte all heading h1 and h2
h1 = soup.select('h1')
h2= soup.select('h2')

# %%
h1
# Out:
# [<h1>Snowflake Python APIs: Managing Snowflake objects with Python<a class="headerlink" data-nosnippet="" href="#sf-python-managing-snowflake-objects-with-python" title="Link to this heading">¶</a></h1>]

# %% [markdown]
# ## FastHTML Rendering

# %%
from fasthtml.common import *
from monsterui.all import *
from fasthtml.jupyter import *

render_ft()
show(render_md(str(h1)))
# Out:
# <p class="text-lg leading-relaxed mb-6">[</p><h1 class="uk-h1 text-4xl font-bold mt-12 mb-6">Snowflake Python APIs: Managing Snowflake objects with Python<a class="headerlink uk-link text-primary hover:text-primary-focus underline" data-nosnippet="" href="#sf-python-managing-snowflake-objects-with-python" title="Link to this heading">¶</a></h1>]
# <script>if (window.htmx) htmx.process(document.body)</script>

# %%
tr= soup.select('tr')

# %%
show(render_md(str(tr)))
# Out:
# <p class="text-lg leading-relaxed mb-6">[</p><tr class="row-odd"><th class="head !text-left p-2 font-semibold"><p class="text-lg leading-relaxed mb-6">Guide</p></th>
# <th class="head !text-left p-2 font-semibold"><p class="text-lg leading-relaxed mb-6">Description</p></th>
# </tr>, <tr class="row-even"><td class="p-2"><p class="text-lg leading-relaxed mb-6"><a class="reference internal uk-link text-primary hover:text-primary-focus underline" href="snowflake-python-installing"><span class="doc">Install the Snowflake Python APIs library</span></a></p></td>
# <td class="p-2"><p class="text-lg leading-relaxed mb-6">Install the Snowflake Python APIs package.</p></td>
# </tr>, <tr class="row-odd"><td class="p-2"><p class="text-lg leading-relaxed mb-6"><a class="reference internal uk-link text-primary hover:text-primary-focus underline" href="snowflake-python-connecting-snowflake"><span class="doc">Connect to Snowflake with the Snowflake Python APIs</span></a></p></td>
# ...

# %%
show(soup.select('td'))
# Out:
# [<td><p><a class="reference internal" href="snowflake-python-installing"><span class="doc">Install the Snowflake Python APIs library</span></a></p></td>, <td><p>Install the Snowflake Python APIs package.</p></td>, <td><p><a class="reference internal" href="snowflake-python-connecting-snowflake"><span class="doc">Connect to Snowflake with the Snowflake Python APIs</span></a></p></td>, <td><p>Connect to Snowflake from Python code.</p></td>, <td><p><a class="reference internal" href="snowflake-python-managing-accounts"><span class="doc">Managing Snowflake accounts and managed accounts with Python</span></a></p></td>, <td><p>Use the API to create and manage accounts and managed accounts.</p></td>, <td><p><a class="reference internal" href="snowflake-python-managing-alerts"><span class="doc">Managing Snowflake alerts with Python</span></a></p></td>, <td><p>Use the API to create and manage alerts.</p></td>, <td><p><a class="reference internal" href="snowflake-python-managing-data-loading">
# ...

# %% [markdown]
# whats is xpath...
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# XPath (XML Path Language) is a query language for selecting nodes from an XML or HTML document. It's similar to what you've been doing with CSS selectors in BeautifulSoup, but uses a different syntax and is often more powerful for complex selections.
#
# For example:
# - CSS selector: `soup.select('h1')`
# - XPath equivalent: `//h1`
#
# XPath can do things like:
# - Select elements by their position: `//tr[2]` (second `<tr>`)
# - Navigate to parent elements: `//td/..` (parent of `<td>`)
# - Select based on text content: `//a[contains(text(), 'Guide')]`
#
# Are you interested in using XPath for a specific task, or would you like to understand how it compares to the CSS selectors you've been using with BeautifulSoup?

# %% [markdown]
# ## Dialog Tools

# %%
tool_info()

# %% [markdown]
# Tools available from `dialoghelper`:
#
# - &`curr_dialog`: Get the current dialog info.
# - &`msg_idx`: Get absolute index of message in dialog.
# - &`add_html`: Send HTML to the browser to be swapped into the DOM using hx-swap-oob.
# - &`find_msg_id`: Get the current message id.
# - &`find_msgs`: Find messages in current specific dialog that contain the given information.
#   - (solveit can often get this id directly from its context, and will not need to use this if the required information is already available to it.)
# - &`read_msg`: Get the message indexed in the current dialog.
#   - To get the exact message use `n=0` and `relative=True` together with `msgid`.
#   - To get a relative message use `n` (relative position index).
#   - To get the nth message use `n` with `relative=False`, e.g `n=0` first message, `n=-1` last message.
# - &`del_msg`: Delete a message from the dialog.
# - &`add_msg`: Add/update a message to the queue to show after code execution completes.
# - &`update_msg`: Update an existing message.
# - &`url2note`: Read URL as markdown, and add a note below current message with the result
# - &`msg_insert_line`: Insert text at a specific location in a message.
# - &`msg_str_replace`: Find and replace text in a message.
# - &`msg_strs_replace`: Find and replace multiple strings in a message.
# - &`msg_replace_lines`: Replace a range of lines in a message with new content.
#   - Always first use `read_msg( msgid=msgid, n=0, relative=True, nums=True)` to view the content with line numbers.

# %% [markdown]
# Use & `[add_msg]` to go back and add suitable concise markdown h2 header notes before each section of this dialog. By "section" I mean where we change to a different topic (e.g setting, etc). I'm thinking there might be mutiple section
#
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Let me first look at the dialog structure to identify the different sections.
#
# <details class='tool-usage-details'>
#
# ```json
# {
#   "id": "toolu_01CYDDYk1Vr7XmMWQqc7A2Dd",
#   "call": {
#     "function": "curr_dialog",
#     "arguments": {
#       "with_messages": "True"
#     }
#   },
#   "result": "{'name': 'lessons/test_5_dec/nbs/00_core', 'mode': 'learning'}"
# }
# ```
#
# </details>
#
#
#
# <details class='tool-usage-details'>
#
# ```json
# {
#   "id": "toolu_015TnmrfujSmyapQMuhLLo61",
#   "call": {
#     "function": "find_msgs",
#     "arguments": {
#       "include_output": "False"
#     }
#   },
#   "result": "[{'id': '_b32d5aa1',\n  'input_tokens': 15,\n  'output_tokens': 0,\n  'time_run': '',\n  'is_exported': <TRUNCATED>"
# }
# ```
#
# </details>
#
# I can see the following sections:
#
# 1. **nbdev setup** (messages `_b32d5aa1` through `_a4cdf152`) - Module setup and function definitions
# 2. **Web scraping with BeautifulSoup** (starting at `_1439bf4f`) - Fetching and parsing Snowflake docs
# 3. **FastHTML rendering** (starting at `_e915836b`) - Using MonsterUI to render HTML
# 4. **Dialog tools** (starting at `_95f94626`) - Tool info and usage
#
# Let me add the section headers:
#
# <details class='tool-usage-details'>
#
# ```json
# {
#   "id": "toolu_01FKUN7DrK9wYkuLuAqmxGqf",
#   "call": {
#     "function": "add_msg",
#     "arguments": {
#       "content": "## nbdev Module Setup",
#       "msg_type": "note",
#       "msgid": "_dd36a6e3",
#       "placement": "add_before"
#     }
#   },
#   "result": "'_4a49dcd3'"
# }
# ```
#
# </details>
#
#
#
# <details class='tool-usage-details'>
#
# ```json
# {
#   "id": "toolu_018aqdTVYobakLrSUoqK1ZGQ",
#   "call": {
#     "function": "add_msg",
#     "arguments": {
#       "content": "## Web Scraping with BeautifulSoup",
#       "msg_type": "note",
#       "msgid": "_1439bf4f",
#       "placement": "add_before"
#     }
#   },
#   "result": "'_3180df80'"
# }
# ```
#
# </details>
#
#
#
# <details class='tool-usage-details'>
#
# ```json
# {
#   "id": "toolu_01R8rUU9t6wLunYBdE2iTJ4d",
#   "call": {
#     "function": "add_msg",
#     "arguments": {
#       "content": "## FastHTML Rendering",
#       "msg_type": "note",
#       "msgid": "_e915836b",
#       "placement": "add_before"
#     }
#   },
#   "result": "'_0b4f3191'"
# }
# ```
#
# </details>
#
#
#
# <details class='tool-usage-details'>
#
# ```json
# {
#   "id": "toolu_01NE121B35SgoQzUSiqEnhRP",
#   "call": {
#     "function": "add_msg",
#     "arguments": {
#       "content": "## Dialog Tools",
#       "msg_type": "note",
#       "msgid": "_95f94626",
#       "placement": "add_before"
#     }
#   },
#   "result": "'_a13a2b8e'"
# }
# ```
#
# </details>
#
# Done! I've added four h2 section headers:
#
# 1. **## nbdev Module Setup** — before the `#| default_exp core` cell
# 2. **## Web Scraping with BeautifulSoup** — before the httpx/BeautifulSoup imports
# 3. **## FastHTML Rendering** — before the MonsterUI rendering code
# 4. **## Dialog Tools** — before the `tool_info()` call
#
# Does this organization look right, or would you like me to adjust any of the headers or add more sections?
